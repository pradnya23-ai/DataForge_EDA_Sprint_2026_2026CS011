# %%
import os

print("Current folder:")
print(os.getcwd())

print("\nFiles and folders here:")
print(os.listdir())
# Out:
# Current folder:
# C:\Users\PARTH\DataForge_Submission_Pradnya\DataForge_EDA_Sprint_2026_2026CS011\04_python\notebooks
#
# Files and folders here:
# ['.ipynb_checkpoints', '07_dataframe_schema.ipynb']

# %%
df = pd.read_excel("02_excel/p2_excel.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df = pd.read_excel("02_excel/p2_excel.xlsx")
#
# File ~\DataForge_Submission_Pradnya\.venv\Lib\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
#     487 elif engine and engine != io.engine:
#     488     raise ValueError(
# ...
